# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\employee_salary_dataset.csv")
df.plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
a=df.set_index('Name')

# %%
b=a[['Age','Monthly_Salary']]
b
# Out:
#              Age  Monthly_Salary
# Name
# Employee_1    53          111416
# Employee_2    25           95271
# Employee_3    51           69064
# Employee_4    44           95091
# Employee_5    36          132450
# Employee_6    50           65818
# Employee_7    57           70525
# Employee_8    34           44830
# Employee_9    53           42429
# Employee_10   28           31893
# Employee_11   43          141381
# Employee_12   49          104909
# Employee_13   23           72333
# Employee_14   27           28436
# Employee_15   49           99290
# Employee_16   49          101213
# Employee_17   41           30895
# Employee_18   51           44738
# Employee_19   32           55746
# Employee_20   49           74377
# Employee_21   46           73404
# Employee_22   54           79045
# Employee_23   22          122888
# Employee_24   48           64790
# Employee_25   34          132455
# Employee_26   24           30600
# Employee_27   27          119660
# ...

# %%
b.plot.barh(figsize=(15,20))
# Out:
# <Axes: ylabel='Name'>

# %%
# a.plot.pie(figsize=(15,8))

# %%
import matplotlib.pyplot as plt

# %%
df['Tax_Salary']=df['Monthly_Salary']*0.05
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
df=pd.read_excel(r"C:\Users\ABHISHEK YADAV\Downloads\Raw data .xlsx")
df
# Out:
#     Id      Name  Lastname  Salary Department  Mobile no.
# 0    1     Anshu    Rajput   90000      Sales  8595787610
# 1    2    Manish     Kumar   62000  Marketing  8595787611
# 2    3     Aadil      Khan   70000    Finance  8595787612
# 3    4   Chandan    Thakur   80000         IT  8595787613
# 4    5      Aman     Anand   20000      Sales  8595787614
# 5    6     Badal     Singh   65000  Marketing  8595787615
# 6    7      Anil     Yadav   55000    Finance  8595787616
# 7    8     Akash     Verma   75000         IT  8595787617
# 8    9      Yash  Kushwaha   25000      Sales  8595787618
# 9   10  Abhishek     Yadav   95000  Marketing  8595787619
# 10  11   Aaditya     Yadav   10000    Finance  8595787620
# 11  12     Daksh   Chauhan   66000         IT  8595787621
# 12  13     Ayush     Singh   30000      Sales  8595787622
# 13  14      Arun     Singh   89000  Marketing  8595787623
# 14  15    Ashish     Rawat   90000    Finance  8595787624
# ...

# %%
t= df['Name']
t2=list(t)
t2

# %%
s=df['Salary']
s2=list(s)
s2

# %%
plt.pie(s2,labels=t2,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1beaa8ecc20>,
# ...
#  [Text(1.077223338784125, 0.22268784964335706, 'Anshu'),
#   Text(0.9388467572663315, 0.5732074374696251, 'Manish'),
#   Text(0.7283584151596845, 0.8243142720261932, 'Aadil'),
#   Text(0.41201587049499505, 1.0199229982995048, 'Chandan'),
#   Text(0.17244691410784113, 1.0863986661510052, 'Aman'),
#   Text(-0.03861088241705942, 1.0993221546748597, 'Badal'),
#   Text(-0.3323271321353267, 1.0485984346959083, 'Anil'),
#   Text(-0.6223451795187003, 0.9070206599244787, 'Akash'),
#   Text(-0.8101395236525273, 0.7440927040470539, 'Yash'),
#   Text(-0.980163673424864, 0.49927865295671986, 'Abhishek'),
#   Text(-1.070200281845017, 0.25430563646692217, 'Aaditya'),
#   Text(-1.097943629641707, 0.06722935466887879, 'Daksh'),
#   Text(-1.0865932206812352, -0.17121674208318766, 'Ayush'),
#   Text(-1.0017680986706177, -0.4543794410906546, 'Arun'),
#   Text(-0.7413360557803805, -0.812662815932899, 'Ashish'),
# ...
