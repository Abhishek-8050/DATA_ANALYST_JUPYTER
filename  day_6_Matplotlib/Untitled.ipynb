# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\employee_salary_dataset.csv")
df.plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
a=df.set_index('Name')

# %%
b=a[['Monthly_Salary','Age']]

# %%
b.plot.barh(figsize=(15,20))
# Out:
# <Axes: ylabel='Name'>

# %%
# a.plot.pie(figsize=(15,8))

# %%
import matplotlib.pyplot as plt

# %%
df['Tax_Salary']=df['Monthly_Salary']*0.05
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# 12          13  Employee_13  Operations                 2          Master
# 13          14  Employee_14     Finance                 6        Bachelor
# 14          15  Employee_15   Marketing                10             PhD
# 15          16  Employee_16     Finance                 4     High School
# 16          17  Employee_17   Marketing                18          Master
# 17          18  Employee_18  Operations                12             PhD
# 18          19  Employee_19          HR                 2             PhD
# 19          20  Employee_20   Marketing                10        Bachelor
# 20          21  Employee_21     Finance                 4          Master
# 21          22  Employee_22  Operations                14          Master
# 22          23  Employee_23   Marketing                16     High School
# 23          24  Employee_24          HR                15          Master
# 24          25  Employee_25          HR                 8     High School
# 25          26  Employee_26          IT                14          Master
# 26          27  Employee_27          IT                 8        Bachelor
# 27          28  Employee_28     Finance                16          Master
# 28          29  Employee_29   Marketing                13     High School
# 29          30  Employee_30   Marketing                18     High School
# 30          31  Employee_31          IT                15        Bachelor
# 31          32  Employee_32   Marketing                13          Master
# 32          33  Employee_33   Marketing                 9          Master
# 33          34  Employee_34          HR                15        Bachelor
# 34          35  Employee_35          IT                13          Master
# 35          36  Employee_36  Operations                 1          Master
# 36          37  Employee_37          IT                 7     High School
# 37          38  Employee_38  Operations                 9          Master
# 38          39  Employee_39          HR                 1          Master
# 39          40  Employee_40     Finance                12        Bachelor
# 40          41  Employee_41   Marketing                 8        Bachelor
# 41          42  Employee_42          HR                11             PhD
# 42          43  Employee_43   Marketing                19     High School
# 43          44  Employee_44     Finance                17          Master
# 44          45  Employee_45     Finance                 8          Master
# 45          46  Employee_46          HR                 3             PhD
# 46          47  Employee_47     Finance                 3          Master
# 47          48  Employee_48  Operations                 1     High School
# 48          49  Employee_49     Finance                 5             PhD
# 49          50  Employee_50   Marketing                10     High School
#
#     Age  Gender       City  Monthly_Salary  Tax_Salary
# 0    53  Female      Delhi          111416     5570.80
# 1    25  Female  Bangalore           95271     4763.55
# 2    51  Female  Hyderabad           69064     3453.20
# 3    44    Male      Delhi           95091     4754.55
# 4    36  Female      Delhi          132450     6622.50
# 5    50    Male     Mumbai           65818     3290.90
# 6    57    Male     Mumbai           70525     3526.25
# 7    34  Female  Bangalore           44830     2241.50
# 8    53    Male  Hyderabad           42429     2121.45
# 9    28    Male     Mumbai           31893     1594.65
# 10   43    Male      Delhi          141381     7069.05
# 11   49  Female  Hyderabad          104909     5245.45
# 12   23  Female  Hyderabad           72333     3616.65
# 13   27    Male      Delhi           28436     1421.80
# 14   49  Female     Mumbai           99290     4964.50
# 15   49  Female      Delhi          101213     5060.65
# 16   41  Female  Hyderabad           30895     1544.75
# 17   51  Female    Chennai           44738     2236.90
# 18   32    Male    Chennai           55746     2787.30
# 19   49    Male  Bangalore           74377     3718.85
# 20   46  Female      Delhi           73404     3670.20
# 21   54  Female      Delhi           79045     3952.25
# 22   22    Male  Bangalore          122888     6144.40
# 23   48    Male  Bangalore           64790     3239.50
# 24   34  Female  Bangalore          132455     6622.75
# 25   24    Male  Hyderabad           30600     1530.00
# 26   27  Female      Delhi          119660     5983.00
# 27   29  Female  Hyderabad          118179     5908.95
# 28   48    Male  Bangalore           65764     3288.20
# 29   30    Male      Delhi           99543     4977.15
# 30   54  Female  Hyderabad           70714     3535.70
# 31   45  Female  Hyderabad           81835     4091.75
# 32   36    Male  Bangalore          127946     6397.30
# 33   53  Female      Delhi          134616     6730.80
# 34   53    Male  Bangalore          130983     6549.15
# 35   45  Female      Delhi           98744     4937.20
# 36   33    Male    Chennai           81491     4074.55
# 37   23    Male     Mumbai          149123     7456.15
# 38   24    Male     Mumbai           43589     2179.45
# 39   38  Female     Mumbai           68484     3424.20
# 40   23  Female  Bangalore          107989     5399.45
# 41   23    Male    Chennai           61212     3060.60
# 42   49  Female      Delhi           68525     3426.25
# 43   44    Male  Hyderabad           72202     3610.10
# 44   53    Male      Delhi           57635     2881.75
# 45   54  Female  Hyderabad           88208     4410.40
# 46   22  Female      Delhi           58828     2941.40
# 47   40    Male    Chennai           43711     2185.55
# 48   23  Female  Hyderabad           28420     1421.00
# 49   47  Female  Bangalore          121752     6087.60

# %%
df=pd.read_excel(r"C:\Users\ABHISHEK YADAV\Downloads\Raw data .xlsx")
df

# %%
id=df['Id']
Id=list(id)
Id

# %%
t= df['Name']
t2=list(t)
t2

# %%
s=df['Salary']
s2=list(s)
s2

# %%
plt.pie(s2,labels=t2,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x26a7d266850>,
#   <matplotlib.patches.Wedge at 0x26a7d266d50>,
#   <matplotlib.patches.Wedge at 0x26a7d267250>,
#   <matplotlib.patches.Wedge at 0x26a7d267750>],
#  [Text(0.950288350846109, 0.5540325353678992, 'Devils'),
#   Text(-0.5741520663348747, 0.9382693668256434, 'Kings'),
#   Text(-0.5233842282502879, -0.9675065630882567, 'Riders'),
#   Text(0.9561364016461887, -0.5438779104239095, 'Royals')],
#  [Text(0.518339100461514, 0.3021995647461268, '16.8%'),
#   Text(-0.31317385436447703, 0.5117832909958054, '33.9%'),
#   Text(-0.2854823063183388, -0.5277308525935944, '32.9%'),
#   Text(0.5215289463524665, -0.29666067841304156, '16.5%')])

# %%
p=['blue','red','green','yellow','orange','pink','black','brown','purple','magenta','blue','red','green','yellow','orange','pink','black','brown','purple','magenta']
p
# Out:
# ['blue',
#  'red',
#  'green',
#  'yellow',
#  'orange',
#  'pink',
#  'black',
#  'brown',
#  'purple',
#  'magenta',
#  'blue',
#  'red',
#  'green',
#  'yellow',
#  'orange',
#  'pink',
#  'black',
#  'brown',
#  'purple',
#  'magenta']

# %%
plt.figure(figsize=(10,8))
plt.barh(t2,s2,color=p)
plt.xlabel('Name',size=20,color='red')
plt.ylabel('Salary',size=20,color='brown')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Salary Of Employees',size=20,color='red')
# Out:
# Text(0.5, 1.0, 'Salary Of Employees')

# %%
t2
# Out:
# ['Devils', 'Kings', 'Riders', 'Royals']

# %%
s2
# Out:
# [1536, 3097, 3004, 1505]

# %%
e=(0,0,0.3,0,0,0,0.4,0,0,0,0,0,0,0.4,0,0,0.5,0,0,0)
plt.figure(figsize=(15,7))
plt.pie(s2,explode=e,labels=t2,autopct='%1.1f%%',shadow=True,colors=p)
plt.title('Employees Salary',size=15,color='Green')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 3
#       1 e=(0,0,0.3,0,0,0,0.4,0,0,0,0,0,0,0.4,0,0,0.5,0,0,0)
#       2 plt.figure(figsize=(15,7))
# ----> 3 plt.pie(s2,explode=e,labels=t2,autopct='%1.1f%%',shadow=True,colors=p)
#       4 plt.title('Employees Salary',size=15,color='Green')
#       5 plt.legend()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3806, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3783 @_copy_docstring_and_deprecators(Axes.pie)
#    3784 def pie(
#    3785     x: ArrayLike,
#    (...)   3804     data=None,
#    3805 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3806     return gca().pie(
#    3807         x,
#    3808         explode=explode,
#    3809         labels=labels,
#    3810         colors=colors,
#    3811         autopct=autopct,
#    3812         pctdistance=pctdistance,
#    3813         shadow=shadow,
#    3814         labeldistance=labeldistance,
#    3815         startangle=startangle,
#    3816         radius=radius,
#    3817         counterclock=counterclock,
#    3818         wedgeprops=wedgeprops,
#    3819         textprops=textprops,
#    3820         center=center,
#    3821         frame=frame,
#    3822         rotatelabels=rotatelabels,
#    3823         normalize=normalize,
#    3824         hatch=hatch,
#    3825         **({"data": data} if data is not None else {}),
#    3826     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:3378, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3376     raise ValueError(f"'labels' must be of length 'x', not {len(labels)}")
#    3377 if len(x) != len(explode):
# -> 3378     raise ValueError(f"'explode' must be of length 'x', not {len(explode)}")
#    3379 if colors is None:
#    3380     get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x', not 20

# %%
ipl={'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Riders'],
     'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
     'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
     'Points':[876,789,863,673,741,812,756,788,649,701,804,690]}
df=pd.DataFrame(ipl)
df

# %%
h=df.groupby('Team')
h

# %%
p=h['Points'].sum()
p

# %%
g=pd.DataFrame(p)
g

# %%
n=g.reset_index()
n
# Out:
#      Team  Points
# 0  Devils    1536
# 1   Kings    3097
# 2  Riders    3004
# 3  Royals    1505

# %%
t=n['Team']
t2=list(t)
t2
# Out:
# ['Devils', 'Kings', 'Riders', 'Royals']

# %%
s=n['Points']
s2=list(s)
s2
# Out:
# [1536, 3097, 3004, 1505]

# %%
plt.figure(figsize=(15,3))
plt.barh(t2,s2,color='purple')
plt.xlabel('Team',size=20,color='red',fontweight='bold')
plt.ylabel('Points',size=20,color='red',fontweight='bold')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Team Records Report',size=20,color='red',fontweight='bold')

for index,value in enumerate(s2):
    plt.text(value,index,str(value))

plt.show()

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     884
# 11  Royals     2  2017     690

# %%
import pandas as pd
df2= {'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Royals'],
            'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
            'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
            'Points':[876,789,863,673,741,812,756,788,694,701,884,690],
            
           }
df=pd.DataFrame(df2)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     884
# 11  Royals     2  2017     690

# %%
h=df.groupby('Team')['Points'].sum()
h
# for i,j in h:
#     print(i)
#     print(j)
# Out:
# Team
# Devils    1536
# Kings     3097
# Riders    2359
# Royals    2275
# Name: Points, dtype: int64

# %%
plt.plot(h)
