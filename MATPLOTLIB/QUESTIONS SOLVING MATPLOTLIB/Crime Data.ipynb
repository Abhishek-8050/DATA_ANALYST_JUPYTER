# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\OneDrive\Desktop\crime_dataset_india.csv")
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
# Q1. City-wise total crime count ka bar chart banao. Kaun sa city me sabse zyada crimes hue?
a=df['City'].value_counts()
plt.figure(figsize=(10,10))
plt.barh(a.index,a.values)
plt.xlabel('crime count')
plt.ylabel('City')
plt.title('City-wise total crime count ')
# Out:
# Text(0.5, 1.0, 'City-wise total crime count ')

# %%
# Q2. Crime Domain (Violent Crime vs Other Crime) ka bar chart banao.Kaunsa domain zyada common hai?

filter_data=df[df['Crime Domain'].isin(['Violent Crime','Other Crime'])]
a=filter_data['Crime Domain'].value_counts()
plt.figure(figsize=(10,5))
plt.bar(a.index, a.values)
plt.xlabel('Crime Domain')
plt.ylabel('Number of Crimes')
plt.title('Crime Domain Distribution')
for i,j in enumerate(a.values):
     plt.text(i,j,str(j),ha='center')
plt.show()




# -------------THIS IS FOR ALL CRIME DOMAIN DATA CRIME ----------------------
# df['Crime Domain'].value_counts()
# plt.figure(figsize=(20,10))
# plt.bar(a.index, a.values)

# plt.xlabel('Crime Domain')
# plt.ylabel('Number of Crimes')
# plt.title('Crime Domain Distribution')
# for i,j in enumerate(a.values):
#     plt.text(i,j,str(j),ha='center')

# plt.show()

# %%
#️Q3.  Weapon Used ka frequency bar chart banao. Sabse zyada kaunsa weapon use hua?
a=df['Weapon Used'].value_counts()
plt.figure(figsize=(10,5))
plt.bar(a.index,a.values)
plt.xlabel('Weapon Count')
plt.ylabel('Weapon Name')
plt.title('Weapon Used frequency')
for i,j in enumerate(a.values):
    plt.text(i,j,str(j))
plt.show()

# %%
# Q4 .Victim Gender distribution ka pie chart banao.Male vs Female victim ratio kya hai?
a=df['Victim Gender'].value_counts() 
plt.figure(figsize=(6,6))

plt.pie(
    a.values,
    labels=a.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Victim Gender Distribution')
plt.show()

# %%
# Q5. Victim Age ka histogram banao.Age distribution kaisa hai? Skewed ya symmetric?
plt.figure(figsize=(8,5))

plt.hist(df['Victim Age'], bins=15)

plt.xlabel('Victim Age')
plt.ylabel('Frequency')
plt.title('Victim Age Distribution')

plt.show()

# %%
df['Victim Age'].value_counts()
# Out:
# Victim Age
# 25    636
# 22    636
# 35    619
# 34    612
# 40    608
#      ...
# 31    538
# 57    535
# 12    534
# 71    531
# 52    523
# Name: count, Length: 70, dtype: int64

# %%
# Q6. Case Closed (Yes/No) ka bar chart banao.Kitne percent cases close hue hain?
a=df['Case Closed'].value_counts()
plt.figure(figsize=(10,5))
plt.bar(a.index,a.values)
plt.xlabel('cases yes/no')
plt.ylabel('Frequency')
plt.title('Case closed chart')
plt.show()

# %%
# Q7. Year-wise crime trend ka line plot banao. Kya crimes time ke saath increase ho rahe hain?
df['Date of Occurrence']=pd.to_datetime(df['Date of Occurrence'])

# %%
df['Year']=df['Date of Occurrence'].dt.year
df
# Out:
#        Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...              ...               ...                 ...                ...
# 40155          40156  01-08-2024 16:00 2024-07-31 03:00:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00 2024-07-31 04:00:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00 2024-07-31 05:00:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00 2024-07-31 06:00:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00 2024-07-31 07:00:00   31-07-2024 17:19
#
# ...

# %%
a=df['Year'].value_counts()
a
plt.figure(figsize=(15,5))
plt.plot(a,marker='o')
plt.xlabel('Years')
plt.ylabel('Crime rate ')
plt.title('year wise crime trend')
plt.show()

# %%
# Q8 Month-wise crime trend plot karo. Kya seasonality exist karti hai?
df['Months']=df['Date of Occurrence'].dt.month_name()
a=df['Months'].value_counts()
plt.figure(figsize=(15,5))
plt.plot(a,marker='o')
plt.xlabel('Years')
plt.ylabel('Crime rate ')
plt.title('Months wise crime trend')
plt.show()

# %%
# Q9. City-wise violent crimes ka stacked bar chart banao. Har city me violent vs non-violent compare karo.
df
# Out:
#        Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...              ...               ...                 ...                ...
# 40155          40156  01-08-2024 16:00 2024-07-31 03:00:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00 2024-07-31 04:00:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00 2024-07-31 05:00:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00 2024-07-31 06:00:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00 2024-07-31 07:00:00   31-07-2024 17:19
#
# ...
